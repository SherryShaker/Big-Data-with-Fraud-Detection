# %%
from pyspark.context import SparkConf, SparkContext
from pyspark.sql.session import SparkSession

spark = SparkSession.builder.master("local[*]").config("spark.driver.memory", "20g").appName("Train_ml").getOrCreate()

train = spark.read.options(header='true').csv("10k.csv")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-2-7bbef849f4ca> in <module>
#       4 spark = SparkSession.builder.master("local[*]").config("spark.driver.memory", "20g").appName("Train_ml").getOrCreate()
#       5
# ----> 6 train = spark.read.options(header='true').csv("10k.csv")
#
# J:\Anaconda\Anaconda3\lib\site-packages\pyspark\sql\readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     735             path = [path]
#     736         if type(path) == list:
# --> 737             return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     738         elif isinstance(path, RDD):
#     739             def func(iterator):
#
# J:\Anaconda\Anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#    1307         for temp_arg in temp_args:
#
# J:\Anaconda\Anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: Path does not exist: file:/C:/Users/DELL/Desktop/BD01-files-2021/model_tunning/10k.csv

# %%
# drop null columns and columns(V, C, D) with correlation larger than 0.95
null_drop = ['dist2', 'D6', 'D7', 'D8', 'D9', 'D12', 'D13', 'D14', 'V138', 'V139', 'V140', 'V141', 'V142', 'V143', 'V144', 'V145', 'V146', 'V147', 'V148', 'V149', 'V150', 'V151', 'V152', 'V153', 'V154', 'V155', 'V156', 'V157', 'V158', 'V159', 'V160', 'V161', 'V162', 'V163', 'V164', 'V165', 'V166', 'V322', 'V323', 'V324', 'V325', 'V326', 'V327', 'V328', 'V329', 'V330', 'V331', 'V332', 'V333', 'V334', 'V335', 'V336', 'V337', 'V338', 'V339', 'id_03', 'id_04', 'id_07', 'id_08', 'id_09', 'id_10', 'id_14', 'id_18', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_30', 'id_32', 'id_33', 'id_34']
corr_drop_v = ['V3', 'V5', 'V6', 'V8', 'V9', 'V11', 'V16', 'V18', 'V22', 'V26', 'V28', 'V30', 'V32', 'V34', 'V43', 'V46', 'V49', 'V52', 'V58', 'V60', 'V70', 'V72', 'V74','V91', 'V93', 'V97', 'V103', 'V106', 'V128', 'V132', 'V133', 'V134', 'V167', 'V168', 'V178', 'V182', 'V189', 'V21', 'V33', 'V81', 'V101', 'V102', 'V126', 'V127', 'V177', 'V179', 'V193', 'V195', 'V196', 'V197', 'V201', 'V204', 'V211', 'V212', 'V219', 'V222', 'V225', 'V231', 'V232', 'V233', 'V237', 'V241', 'V244', 'V247', 'V249', 'V251', 'V254', 'V256', 'V259', 'V269', 'V272', 'V273', 'V279', 'V280','V292', 'V295', 'V298', 'V304', 'V306', 'V307', 'V316', 'V317', 'V318', 'V293', 'V295', 'V306', 'V308', 'V316', 'V318']
corr_drop_c = ['C2', 'C4', 'C6', 'C8', 'C10', 'C11', 'C12', 'C14']
corr_drop_d = ['D2']
to_drop = null_drop + corr_drop_v + corr_drop_c + corr_drop_d

train = train.drop(*to_drop)
train.printSchema()
# Out:
# root
#  |-- TransactionID: string (nullable = true)
#  |-- isFraud: string (nullable = true)
#  |-- TransactionDT: string (nullable = true)
#  |-- TransactionAmt: string (nullable = true)
#  |-- ProductCD: string (nullable = true)
#  |-- card1: string (nullable = true)
#  |-- card2: string (nullable = true)
#  |-- card3: string (nullable = true)
#  |-- card4: string (nullable = true)
#  |-- card5: string (nullable = true)
#  |-- card6: string (nullable = true)
#  |-- addr1: string (nullable = true)
#  |-- addr2: string (nullable = true)
#  |-- dist1: string (nullable = true)
#  |-- P_emaildomain: string (nullable = true)
#  |-- R_emaildomain: string (nullable = true)
#  |-- C1: string (nullable = true)
#  |-- C3: string (nullable = true)
#  |-- C5: string (nullable = true)
#  |-- C7: string (nullable = true)
#  |-- C9: string (nullable = true)
#  |-- C13: string (nullable = true)
#  |-- D1: string (nullable = true)
#  |-- D3: string (nullable = true)
#  |-- D4: string (nullable = true)
#  |-- D5: string (nullable = true)
#  |-- D10: string (nullable = true)
#  |-- D11: string (nullable = true)
#  |-- D15: string (nullable = true)
#  |-- M1: string (nullable = true)
#  |-- M2: string (nullable = true)
#  |-- M3: string (nullable = true)
#  |-- M4: string (nullable = true)
#  |-- M5: string (nullable = true)
#  |-- M6: string (nullable = true)
#  |-- M7: string (nullable = true)
#  |-- M8: string (nullable = true)
#  |-- M9: string (nullable = true)
#  |-- V1: string (nullable = true)
#  |-- V2: string (nullable = true)
#  |-- V4: string (nullable = true)
#  |-- V7: string (nullable = true)
#  |-- V10: string (nullable = true)
#  |-- V12: string (nullable = true)
#  |-- V13: string (nullable = true)
#  |-- V14: string (nullable = true)
#  |-- V15: string (nullable = true)
#  |-- V17: string (nullable = true)
#  |-- V19: string (nullable = true)
#  |-- V20: string (nullable = true)
#  |-- V23: string (nullable = true)
#  |-- V24: string (nullable = true)
#  |-- V25: string (nullable = true)
#  |-- V27: string (nullable = true)
#  |-- V29: string (nullable = true)
#  |-- V31: string (nullable = true)
#  |-- V35: string (nullable = true)
#  |-- V36: string (nullable = true)
#  |-- V37: string (nullable = true)
#  |-- V38: string (nullable = true)
#  |-- V39: string (nullable = true)
#  |-- V40: string (nullable = true)
#  |-- V41: string (nullable = true)
#  |-- V42: string (nullable = true)
#  |-- V44: string (nullable = true)
#  |-- V45: string (nullable = true)
#  |-- V47: string (nullable = true)
#  |-- V48: string (nullable = true)
#  |-- V50: string (nullable = true)
#  |-- V51: string (nullable = true)
#  |-- V53: string (nullable = true)
#  |-- V54: string (nullable = true)
#  |-- V55: string (nullable = true)
#  |-- V56: string (nullable = true)
#  |-- V57: string (nullable = true)
#  |-- V59: string (nullable = true)
#  |-- V61: string (nullable = true)
#  |-- V62: string (nullable = true)
#  |-- V63: string (nullable = true)
#  |-- V64: string (nullable = true)
#  |-- V65: string (nullable = true)
#  |-- V66: string (nullable = true)
#  |-- V67: string (nullable = true)
#  |-- V68: string (nullable = true)
#  |-- V69: string (nullable = true)
#  |-- V71: string (nullable = true)
#  |-- V73: string (nullable = true)
#  |-- V75: string (nullable = true)
#  |-- V76: string (nullable = true)
#  |-- V77: string (nullable = true)
#  |-- V78: string (nullable = true)
#  |-- V79: string (nullable = true)
#  |-- V80: string (nullable = true)
#  |-- V82: string (nullable = true)
#  |-- V83: string (nullable = true)
#  |-- V84: string (nullable = true)
#  |-- V85: string (nullable = true)
#  |-- V86: string (nullable = true)
#  |-- V87: string (nullable = true)
#  |-- V88: string (nullable = true)
#  |-- V89: string (nullable = true)
#  |-- V90: string (nullable = true)
#  |-- V92: string (nullable = true)
#  |-- V94: string (nullable = true)
#  |-- V95: string (nullable = true)
#  |-- V96: string (nullable = true)
#  |-- V98: string (nullable = true)
#  |-- V99: string (nullable = true)
#  |-- V100: string (nullable = true)
#  |-- V104: string (nullable = true)
#  |-- V105: string (nullable = true)
#  |-- V107: string (nullable = true)
#  |-- V108: string (nullable = true)
#  |-- V109: string (nullable = true)
#  |-- V110: string (nullable = true)
#  |-- V111: string (nullable = true)
#  |-- V112: string (nullable = true)
#  |-- V113: string (nullable = true)
#  |-- V114: string (nullable = true)
#  |-- V115: string (nullable = true)
#  |-- V116: string (nullable = true)
#  |-- V117: string (nullable = true)
#  |-- V118: string (nullable = true)
#  |-- V119: string (nullable = true)
#  |-- V120: string (nullable = true)
#  |-- V121: string (nullable = true)
#  |-- V122: string (nullable = true)
#  |-- V123: string (nullable = true)
#  |-- V124: string (nullable = true)
#  |-- V125: string (nullable = true)
#  |-- V129: string (nullable = true)
#  |-- V130: string (nullable = true)
#  |-- V131: string (nullable = true)
#  |-- V135: string (nullable = true)
#  |-- V136: string (nullable = true)
#  |-- V137: string (nullable = true)
#  |-- V169: string (nullable = true)
#  |-- V170: string (nullable = true)
#  |-- V171: string (nullable = true)
#  |-- V172: string (nullable = true)
#  |-- V173: string (nullable = true)
#  |-- V174: string (nullable = true)
#  |-- V175: string (nullable = true)
#  |-- V176: string (nullable = true)
#  |-- V180: string (nullable = true)
#  |-- V181: string (nullable = true)
#  |-- V183: string (nullable = true)
#  |-- V184: string (nullable = true)
#  |-- V185: string (nullable = true)
#  |-- V186: string (nullable = true)
#  |-- V187: string (nullable = true)
#  |-- V188: string (nullable = true)
#  |-- V190: string (nullable = true)
#  |-- V191: string (nullable = true)
#  |-- V192: string (nullable = true)
#  |-- V194: string (nullable = true)
#  |-- V198: string (nullable = true)
#  |-- V199: string (nullable = true)
#  |-- V200: string (nullable = true)
#  |-- V202: string (nullable = true)
#  |-- V203: string (nullable = true)
#  |-- V205: string (nullable = true)
#  |-- V206: string (nullable = true)
#  |-- V207: string (nullable = true)
#  |-- V208: string (nullable = true)
#  |-- V209: string (nullable = true)
#  |-- V210: string (nullable = true)
#  |-- V213: string (nullable = true)
#  |-- V214: string (nullable = true)
#  |-- V215: string (nullable = true)
#  |-- V216: string (nullable = true)
#  |-- V217: string (nullable = true)
#  |-- V218: string (nullable = true)
#  |-- V220: string (nullable = true)
#  |-- V221: string (nullable = true)
#  |-- V223: string (nullable = true)
#  |-- V224: string (nullable = true)
#  |-- V226: string (nullable = true)
#  |-- V227: string (nullable = true)
#  |-- V228: string (nullable = true)
#  |-- V229: string (nullable = true)
#  |-- V230: string (nullable = true)
#  |-- V234: string (nullable = true)
#  |-- V235: string (nullable = true)
#  |-- V236: string (nullable = true)
#  |-- V238: string (nullable = true)
#  |-- V239: string (nullable = true)
#  |-- V240: string (nullable = true)
#  |-- V242: string (nullable = true)
#  |-- V243: string (nullable = true)
#  |-- V245: string (nullable = true)
#  |-- V246: string (nullable = true)
#  |-- V248: string (nullable = true)
#  |-- V250: string (nullable = true)
#  |-- V252: string (nullable = true)
#  |-- V253: string (nullable = true)
#  |-- V255: string (nullable = true)
#  |-- V257: string (nullable = true)
#  |-- V258: string (nullable = true)
#  |-- V260: string (nullable = true)
#  |-- V261: string (nullable = true)
#  |-- V262: string (nullable = true)
#  |-- V263: string (nullable = true)
#  |-- V264: string (nullable = true)
#  |-- V265: string (nullable = true)
#  |-- V266: string (nullable = true)
#  |-- V267: string (nullable = true)
#  |-- V268: string (nullable = true)
#  |-- V270: string (nullable = true)
#  |-- V271: string (nullable = true)
#  |-- V274: string (nullable = true)
#  |-- V275: string (nullable = true)
#  |-- V276: string (nullable = true)
#  |-- V277: string (nullable = true)
#  |-- V278: string (nullable = true)
#  |-- V281: string (nullable = true)
#  |-- V282: string (nullable = true)
#  |-- V283: string (nullable = true)
#  |-- V284: string (nullable = true)
#  |-- V285: string (nullable = true)
#  |-- V286: string (nullable = true)
#  |-- V287: string (nullable = true)
#  |-- V288: string (nullable = true)
#  |-- V289: string (nullable = true)
#  |-- V290: string (nullable = true)
#  |-- V291: string (nullable = true)
#  |-- V294: string (nullable = true)
#  |-- V296: string (nullable = true)
#  |-- V297: string (nullable = true)
#  |-- V299: string (nullable = true)
#  |-- V300: string (nullable = true)
#  |-- V301: string (nullable = true)
#  |-- V302: string (nullable = true)
#  |-- V303: string (nullable = true)
#  |-- V305: string (nullable = true)
#  |-- V309: string (nullable = true)
#  |-- V310: string (nullable = true)
#  |-- V311: string (nullable = true)
#  |-- V312: string (nullable = true)
#  |-- V313: string (nullable = true)
#  |-- V314: string (nullable = true)
#  |-- V315: string (nullable = true)
#  |-- V319: string (nullable = true)
#  |-- V320: string (nullable = true)
#  |-- V321: string (nullable = true)
#  |-- id_01: string (nullable = true)
#  |-- id_02: string (nullable = true)
#  |-- id_05: string (nullable = true)
#  |-- id_06: string (nullable = true)
#  |-- id_11: string (nullable = true)
#  |-- id_12: string (nullable = true)
#  |-- id_13: string (nullable = true)
#  |-- id_15: string (nullable = true)
#  |-- id_16: string (nullable = true)
#  |-- id_17: string (nullable = true)
#  |-- id_19: string (nullable = true)
#  |-- id_20: string (nullable = true)
#  |-- id_28: string (nullable = true)
#  |-- id_29: string (nullable = true)
#  |-- id_31: string (nullable = true)
#  |-- id_35: string (nullable = true)
#  |-- id_36: string (nullable = true)
#  |-- id_37: string (nullable = true)
#  |-- id_38: string (nullable = true)
#  |-- DeviceType: string (nullable = true)
#  |-- DeviceInfo: string (nullable = true)

# %%
# define functions to transform data to numerical(float) or categorical type and fill null with -999
from pyspark.sql.functions import isnan, when, count, col
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline, Transformer
from typing import Iterable
from pyspark.sql import DataFrame

# CUSTOM TRANSFORMER ----------------------------------------------------------------
class NumericalTransform(Transformer):
    def __init__(self, numerical: Iterable[str]):
        super(NumericalTransform, self).__init__()
        self.numerical = numerical
    def _transform(self, df: DataFrame) -> DataFrame:
        for col_name in numerical:
            df = df.withColumn(col_name, col(col_name).cast('float'))   
        df = df.withColumn('isFraud', col('isFraud').cast('float'))
        df = df.na.fill(-999, numerical)
        return df
    
# CUSTOM TRANSFORMER ----------------------------------------------------------------
class CategoricalFillNull(Transformer):
    def __init__(self, categorical: Iterable[str]):
        super(CategoricalFillNull, self).__init__()
        self.categorical = categorical
    def _transform(self, df: DataFrame) -> DataFrame:
        df = df.na.fill(-999, categorical)
        return df

# %%
# show categorial column names after dropping columns
raw_features = train.columns
raw_features.remove('isFraud')

categorical = ['ProductCD',
               'card1','card2','card3','card4','card5','card6', 
               'addr1', 'addr2',
               'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9',
               'P_emaildomain', 'R_emaildomain',
               'DeviceType','DeviceInfo',
               'id_12',  'id_13', 'id_14',  'id_15',
               'id_16',  'id_17',  'id_18',  'id_19',  'id_20',
               'id_21',  'id_22',  'id_23',  'id_24',  'id_25',
               'id_26',  'id_27',  'id_28',  'id_29',  'id_30',
               'id_31',  'id_32',  'id_33',  'id_34',  'id_35',  'id_36',  'id_37',  'id_38']
categorical = list(set(categorical) - set(to_drop))
print(categorical)
# Out:
# ['id_15', 'ProductCD', 'M2', 'id_17', 'card1', 'id_13', 'id_31', 'id_12', 'id_16', 'addr1', 'card2', 'id_19', 'M3', 'card3', 'M8', 'DeviceInfo', 'id_36', 'P_emaildomain', 'id_37', 'M1', 'M6', 'card4', 'M5', 'addr2', 'card6', 'M9', 'M4', 'id_35', 'DeviceType', 'R_emaildomain', 'id_38', 'id_20', 'id_29', 'card5', 'id_28', 'M7']

# %%
# transform numerical columns to float type
numerical = list(set(raw_features) - set(categorical))
numerical_transform = NumericalTransform(numerical = numerical)

# %%
# fill null categorical data with -999
categorical_output = [x + '_index' for x in categorical]
from pyspark.ml.feature import StringIndexer
indexer = StringIndexer(inputCols=categorical, outputCols=categorical_output, handleInvalid="keep")

categorical_fill_null = CategoricalFillNull(categorical = categorical_output)

# %%
from pyspark.ml.feature import PCA
from pyspark.ml.feature import VectorAssembler

M_features = [s for s in categorical_output if "M" in s]
C_features = [s for s in numerical if "C" in s]
D_features = [s for s in numerical if "D" in s]
V_features = [s for s in numerical if "V" in s]
id_num = [s for s in numerical if "id" in s]
id_cat = [s for s in categorical_output if "id" in s]

all_pca = M_features + C_features + D_features + V_features + id_num + id_cat
all_features = categorical_output + numerical
kept_features = list(set(all_features) - set(all_pca + ['TransactionID']))

assembler_M = VectorAssembler(inputCols=M_features,outputCol="M_features")
pca_M = PCA(k=1, inputCol="M_features", outputCol='pca_M')

assembler_C = VectorAssembler(inputCols=C_features,outputCol="C_features")
pca_C = PCA(k=1, inputCol="C_features", outputCol='pca_C')

assembler_D = VectorAssembler(inputCols=D_features,outputCol="D_features")
pca_D = PCA(k=1, inputCol="D_features", outputCol='pca_D')

assembler_V = VectorAssembler(inputCols=V_features,outputCol="V_features")
pca_V = PCA(k=30, inputCol="V_features", outputCol='pca_V')

assembler_id_num = VectorAssembler(inputCols=id_num,outputCol="id_num")
pca_id_num = PCA(k=1, inputCol="id_num", outputCol='pca_id_num')

assembler_id_cat = VectorAssembler(inputCols=id_cat,outputCol="id_cat")
pca_id_cat = PCA(k=1, inputCol="id_cat", outputCol='pca_id_cat')

pca_features = ['pca_M', 'pca_C', 'pca_D','pca_V','pca_id_num','pca_id_cat']
final_features = pca_features + kept_features
assembler_final = VectorAssembler(inputCols=final_features, outputCol="features")

# %%
# linear svm
from pyspark.ml.classification import LinearSVC

SVC = LinearSVC(featuresCol="features", labelCol="isFraud")

# %%
from pyspark.ml import Pipeline

pipeline = Pipeline(stages=[numerical_transform, indexer, categorical_fill_null,
                           assembler_M, assembler_C, assembler_D, assembler_V, assembler_id_num, assembler_id_cat,
                           pca_M, pca_C, pca_D, pca_V, pca_id_num, pca_id_cat,
                           assembler_final,
                           SVC])

# %%
# cross-fold
from pyspark.ml.tuning import CrossValidator
from pyspark.ml.tuning import ParamGridBuilder
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

(trainingData, testData) = train.randomSplit([0.7, 0.3])
cvModel = cv.fit(trainingData)
grid = ParamGridBuilder().addGrid(SVC.maxIter,[10, 50, 100, 200]).addGrid(SVC.regParam,[0.01, 0.05, 0.1, 1]).build()
evaluator = MulticlassClassificationEvaluator(labelCol="isFraud", predictionCol="prediction", metricName="accuracy")

cv = CrossValidator(estimator=pipeline, 
           estimatorParamMaps=grid,
           evaluator=evaluator,
           numFolds=5,
           parallelism=2)
cvModel = cv.fit(trainingData) # run the crossValidation and automatically select the best combination of paramerters

prediction = cvModel.transform(testData)
evaluator.evaluate(prediction)
# print("Test Accracy = %g" % (accuracy))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6c6067394b3> in <module>
#       4 from pyspark.ml.evaluation import MulticlassClassificationEvaluator
#       5
# ----> 6 (trainingData, testData) = train.randomSplit([0.7, 0.3])
#       7 cvModel = cv.fit(trainingData)
#       8 grid = ParamGridBuilder().addGrid(SVC.maxIter,[10, 50, 100, 200]).addGrid(SVC.regParam,[0.01, 0.05, 0.1, 1]).build()
#
# NameError: name 'train' is not defined

# %%
# Print the best combination of arguments
parameters = [
    (
        [
            {key.name: paramValue} 
            for key, paramValue 
            in zip(
                params.keys(), 
                params.values())
        ], metric
    ) 
    for params, metric 
    in zip(
        cvModel.getEstimatorParamMaps(), 
        cvModel.avgMetrics
    )
]
 
print(sorted(parameters, key=lambda el: el[1], reverse=True))
# Out:
# [([{'maxIter': 200}, {'regParam': 1.0}], 0.9645864649264618), ([{'maxIter': 100}, {'regParam': 1.0}], 0.96444153739023), ([{'maxIter': 10}, {'regParam': 0.01}], 0.9642911614503804), ([{'maxIter': 10}, {'regParam': 0.05}], 0.9642911614503804), ([{'maxIter': 10}, {'regParam': 0.1}], 0.9642911614503804), ([{'maxIter': 10}, {'regParam': 1.0}], 0.9642911614503804), ([{'maxIter': 50}, {'regParam': 1.0}], 0.9642911614503804), ([{'maxIter': 200}, {'regParam': 0.01}], 0.9642911614503804), ([{'maxIter': 200}, {'regParam': 0.05}], 0.9642911614503804), ([{'maxIter': 50}, {'regParam': 0.01}], 0.9641462339141484), ([{'maxIter': 50}, {'regParam': 0.05}], 0.9641462339141484), ([{'maxIter': 50}, {'regParam': 0.1}], 0.9641462339141484), ([{'maxIter': 100}, {'regParam': 0.01}], 0.9641462339141484), ([{'maxIter': 100}, {'regParam': 0.05}], 0.9641462339141484), ([{'maxIter': 100}, {'regParam': 0.1}], 0.9641462339141484), ([{'maxIter': 200}, {'regParam': 0.1}], 0.9641462339141484)]

# %%
grid2 = ParamGridBuilder().addGrid(SVC.maxIter,[200, 500]).addGrid(SVC.regParam,[1, 10]).build()
# evaluator = MulticlassClassificationEvaluator(labelCol="isFraud", predictionCol="prediction", metricName="accuracy")

cv2 = CrossValidator(estimator=pipeline, 
           estimatorParamMaps=grid2,
           evaluator=evaluator,
           numFolds=5,
           parallelism=2)
cvModel2 = cv2.fit(trainingData) # run the crossValidation and automatically select the best combination of paramerters

prediction2 = cvModel2.transform(testData)
evaluator.evaluate(prediction2)

parameters2 = [
    (
        [
            {key.name: paramValue} 
            for key, paramValue 
            in zip(
                params.keys(), 
                params.values())
        ], metric
    ) 
    for params, metric 
    in zip(
        cvModel2.getEstimatorParamMaps(), 
        cvModel2.avgMetrics
    )
]
 
print(sorted(parameters2, key=lambda el: el[1], reverse=True))
# Out:
# [([{'maxIter': 200}, {'regParam': 1.0}], 0.9645864649264618), ([{'maxIter': 200}, {'regParam': 10.0}], 0.9645864649264618), ([{'maxIter': 500}, {'regParam': 1.0}], 0.9645864649264618), ([{'maxIter': 500}, {'regParam': 10.0}], 0.9645864649264618)]
